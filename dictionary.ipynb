# %%
# dictionary

playlist_prices = {
    "Top Hits": 199,
    "Workout Mix": 149,
    "Chill Vibes": 99,
    "Party Songs": 249,
    "Romantic Hits": 179
}

print(playlist_prices)
# Out:
# {'Top Hits': 199, 'Workout Mix': 149, 'Chill Vibes': 99, 'Party Songs': 249, 'Romantic Hits': 179}

# %%
def update_playlist_price(playlist, new_price):
    if playlist in playlist_prices :
        playlist_prices[playlist] = new_price
    else:
        print('playlist not found')

update_playlist_price("Top Hits" ,250)
print(playlist_prices)
# Out:
# playlist not found
# {'Workout Mix': 149, 'Chill Vibes': 99, 'Party Songs': 249, 'Romantic Hits': 179}

# %%
del playlist_prices["Workout Mix"]

print(playlist_prices)
# Out:
# {'Chill Vibes': 99, 'Party Songs': 249, 'Romantic Hits': 179}

# %%
set1 = {"Domino's", "McDonald's", "Burger King", "Subway", "KFC"}

set2 = {"KFC", "Pizza Hut", "Subway", "Bikanervala", "Burger King"}

print(set1.union(set2))
print(set1.intersection(set2))
# Out:
# {'Pizza Hut', 'Bikanervala', "Domino's", 'Burger King', "McDonald's", 'Subway', 'KFC'}
# {'Subway', 'KFC', 'Burger King'}

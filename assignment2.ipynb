# %%
rd='Redmi Note 12 Pro'
print(rd.upper())
print(rd.lower())
# Out:
# REDMI NOTE 12 PRO
# redmi note 12 pro

# %%
def clean_name(name) :
 return name.strip().replace('-',' ')

brand ="onePlus-Nord "
print(clean_name(brand))
# Out:
# onePlus Nord

# %%
# Apple iPhone 14 Pro Max
variable ="Apple iPhone 14 Pro Max"


v =variable.split()
brand=variable[:5]
model=variable[len(brand) + 1:]
model1 = variable[len(v[0]) + 1:]
print(v[0])
print(model1)

print(brand)
print(model)
# Out:
# Apple
# iPhone 14 Pro Max
# Apple
# iPhone 14 Pro Max

# %%
def prodect_name_format(name,price):
    return f"{name} - ₹{price}"

print(prodect_name_format("oppo",200))
# Out:
# oppo - ₹200

# %%
products = [' mi-Band 5 ', ' SAMSUNG-Galaxy ', ' realme-Book ']
clened = []
for product in products :
    product = product.strip().replace('-',' ').title()
    # product = product.replace('-',' ')
    # product = product.title()
    # print(product)
    clened.append(product)

print(clened)
# Out:
# ['Mi Band 5', 'Samsung Galaxy', 'Realme Book']

# %%
# Out:
# 15000
# <class 'int'>
# 4.8
# <class 'float'>
# Instagram
# <class 'str'>
# True
# <class 'bool'>

# %%
# Out:
# [199.99, 299.5, 150.0]
# 649.49
# 649.49

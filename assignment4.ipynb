# %%
user_name = "rd"
fev_app = "instagram"
using_hour = 3

print(f"Name:{user_name}\nApp:{fev_app},\nUsing Hour:{using_hour}")
# Out:
# Name:rd
# App:instagram,
# Using Hour:3

# %%
product_name = "Earphones"
price = 200
is_available = True

print(product_name)
print(type(product_name))

print(price)
print(type(price))

print(is_available)
print(type(is_available))
# Out:
# Earphones
# <class 'str'>
# 200
# <class 'int'>
# True
# <class 'bool'>

# %%
# Spotify Playlist Recommendation System

"""
This program explains how a Spotify playlist recommendation
system might work.

1. It collects the user's listening history.
2. It analyzes favorite artists, genres, and songs.
3. It recommends similar songs and playlists.
"""

# User's favorite genre
favorite_genre = "Pop"

# Display recommendation message
print(f"Recommended playlist based on {favorite_genre} music.")
# Out:
# Recommended playlist based on Pop music.

# %%
order_total=2200
delivery_region = "Hindu"
discount_percent = 20
print(f"Order Form {delivery_region}\nTotal : {order_total}\nGet Discont{discount_percent}")
print(f"Order from {delivery_region} totals ₹{order_total} with {discount_percent}% discount.")
# Out:
# Order Form Hindu
# Total : 2200
# Get Discont20
# Order from Hindu totals ₹2200 with 20% discount.

# %%
name = "Spotify"

if name == "Spotify":
	print("Welcome to Spotify")
	 print("Enjoy your music!")
# Out:
#   Cell In[17], line 5
#     print("Enjoy your music!")
#     ^
# IndentationError: unexpected indent

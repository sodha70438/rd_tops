# %%
followers = 15000

average_rating = 4.8


favorite_app = "Instagram"

is_premium_user = True

print(followers)
print(type(followers))

print(average_rating)
print(type(average_rating))

print(favorite_app)
print(type(favorite_app))

print(is_premium_user)
print(type(is_premium_user))
# Out:
# 15000
# <class 'int'>
# 4.8
# <class 'float'>
# Instagram
# <class 'str'>
# True
# <class 'bool'>

# %%
price =int(input("Enter Zomato order price:"))


final_bill = price + (price * 18 / 100)

# Print final bill
print("Final Bill Amount: ₹", final_bill)
# Out:
# Final Bill Amount: ₹ 29.5

# %%
prices = ['199.99', '299.50', '150']
clean = []
totle = 0 
for price in prices :
    price = float(price)
    totle += price
    clean.append(price)
print(clean)
print(totle)
c=sum(clean)
print(c)
# Out:
# [199.99, 299.5, 150.0]
# 649.49
# 649.49

# %%
def is_discount_applicable(order_amount):
    return order_amount > 500

print(is_discount_applicable(450))
print(is_discount_applicable(750))
# Out:
# False
# True

# %%
sopify_reting = ['4.5', '3.0', '5', '4.2']
rat =[]
for rating in sopify_reting:
    rating = float(rating)
    rat.append(rating)
print(rat)
print(max(rat))
# print(max(rat))
# Out:
# [4.5, 3.0, 5.0, 4.2]
# 5.0

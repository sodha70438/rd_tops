# %%
playlist_ids =[1,2,3,4,5]

playlist_ids.append(6)
print(playlist_ids)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
cart_items =['t-shirt', 'shoes']
ex =['jeans', 'cap']
cart_items.extend(ex)
print(cart_items)
# Out:
# ['t-shirt', 'shoes', 'jeans', 'cap']

# %%
order_list=['Pizza Hut', 'Bikanervala', "Domino's", 'Burger King', "McDonald's", 'Subway', 'KFC']
def remove_last_item(order_list) :
    var  = order_list.pop()
    return var

print(remove_last_item(order_list)) 
print(order_list)
# Out:
# KFC
# ['Pizza Hut', 'Bikanervala', "Domino's", 'Burger King', "McDonald's", 'Subway']

# %%
tup = ('Pizza Hut', 'Bikanervala', "Domino's", 'Burger King', "McDonald's", 'Subway', 'KFC')
tup[1] ="jjjj"

# Tuples are immutable, so their elements cannot be changed after creation.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 tup = ('Pizza Hut', 'Bikanervala', "Domino's", 'Burger King', "McDonald's", 'Subway', 'KFC')
# ----> 2 tup[1] ="jjjj"
#
# TypeError: 'tuple' object does not support item assignment

# %%
train_class = ('Sleeper', 'AC 3 Tier', 'AC 2 Tier') #its fix 

favorite_genres = ["Pop", "Rock", "Hip-Hop"] #it was change
